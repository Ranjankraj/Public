# %% [markdown]
# <a href="https://colab.research.google.com/github/Ranjankraj/Shala/blob/main/DS_L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
num = [13, 4, 23, 12, 9]
tup = ('A', 'B', 'C', 'D', 'E')

plt.bar(tup, num)
plt.xticks(tup)
# Out:
# ([<matplotlib.axis.XTick at 0x7fb153338b00>,
#   <matplotlib.axis.XTick at 0x7fb153338ac8>,
#   <matplotlib.axis.XTick at 0x7fb1533375c0>,
#   <matplotlib.axis.XTick at 0x7fb1532eb208>,
#   <matplotlib.axis.XTick at 0x7fb1532eb630>],
#  <a list of 5 Text major ticklabel objects>)

# %%
plt.barh(tup, num)
plt.yticks(tup)
# Out:
# ([<matplotlib.axis.YTick at 0x7fb153205a90>,
#   <matplotlib.axis.YTick at 0x7fb153205470>,
#   <matplotlib.axis.YTick at 0x7fb15319e198>,
#   <matplotlib.axis.YTick at 0x7fb1531a83c8>,
#   <matplotlib.axis.YTick at 0x7fb1531a8860>],
#  <a list of 5 Text major ticklabel objects>)

# %%
plt.bar(tup, num, color=(0.4, 0.8, 0.2, 0.7), edgecolor='Black')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(tup, num, color=['Red', 'Blue', 'Black', 'Orange', 'Green'], edgecolor="Grey")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(tup, num, color=(0.2, 0.6, 0.1, 0.9))
plt.title('$Height_{bars}$', fontsize=35) #Refer documentation for other Latex formats

plt.xlabel('Name', fontsize=20)
plt.ylabel('Height', fontsize=20)
plt.ylim(0,30)
# Out:
# (0.0, 30.0)

# %%
df = pd.DataFrame({'year': [2015, 2016, 2017, 2018, 2019], 'T20': [24, 36, 12, 18, 25], 'ODI': [89, 24, 37, 63, 98]})

plt.plot('year', 'T20', data=df)
plt.plot('year', 'ODI', data=df)

# %%
plt.plot('year', 'T20', data=df, linewidth=5)
plt.plot('year', 'ODI', data=df, linewidth=5)

plt.xticks(np.arange(min(df.year), max(df.year)+1, 1.0), fontsize = 15)
plt.yticks(np.arange(0,125,25), fontsize = 15)

plt.title('Points scored by India', fontsize = 15)
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Points', fontsize = 15)
plt.legend(loc='upper center')

plt.grid(b=True, alpha=0.9)

# %%
val = np.cumsum(np.random.randn(1000,1))

plt.plot(val)

# %%
a = np.array([[1,2,3], [4,5,6]])
print(a)
np.cumsum(a)
np.cumsum(a,axis=0)
# Out:
# [[1 2 3]
#  [4 5 6]]
# array([[1, 2, 3],
#        [5, 7, 9]])

# %%
# Data
df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21) })
 
# multiple line plot
plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.legend(loc='upper center')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: Second argument 'y1' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: Second argument 'y2' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: Second argument 'y3' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   import sys

# %%
url = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url)
movies.head()
# Out:
#    Unnamed: 0                 title  ...            actor4               actor5
# 0           1           Filly Brown  ...     Emilio Rivera  Joseph Julian Soria
# 1           2              The Dish  ...          Tom Long       Genevieve Mooy
# 2           3   Waiting for Guffman  ...       Eugene Levy          Bob Balaban
# 3           4  The Age of Innocence  ...  Richard E. Grant         Alec McCowen
# 4           5           Malevolence  ...     Heather Magee       Richard Glover
#
# [5 rows x 31 columns]

# %%
sns.regplot(x=movies.critics_score, y=movies.audience_score, ci=100)

# Without regression fit:
# sns.regplot(x=movies["critics_score"], 
#             y = movies["audience_score"], 
#             fit_reg=False)

# %%
# Another example to show the confidence interval
# https://www.mathsisfun.com/data/confidence-interval.html
tips = sns.load_dataset("tips")
#print(tips.head())
#sns.regplot(x="total_bill", y="tip", data=tips, ci = None)
# sns.regplot(x="total_bill", y="tip", data=tips)
sns.regplot(x="total_bill", y="tip", data=tips, ci = 95)

# %%
sns.regplot(tips.total_bill, tips.tip, marker='+', fit_reg=False, color='Red')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(x = movies["critics_score"], 
            y = movies["audience_score"], 
            marker="+", fit_reg=False, scatter_kws={"color":"red", "alpha":0.5, "s":100})

# %%
# Use the 'hue' argument to provide a factor variable
sns.lmplot(x = "critics_score", 
            y = "audience_score", data = movies, fit_reg=False, hue='genre', legend=False)
 
# Move the legend (labeling of plot) to an empty part of the plot
plt.legend(loc='lower right')

# %%
df = sns.load_dataset('iris')
 
# Use the 'hue' argument to provide a factor variable
sns.lmplot(x="sepal_length", y="sepal_width", data=df, fit_reg=False, hue='species', legend=False)
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %%
df = sns.load_dataset('iris')

sns.violinplot(x=df['species'], y=df['sepal_length'])

# %%
p1=sns.kdeplot(df['sepal_width'], shade=True, color='r')
p2=sns.kdeplot(df['sepal_length'], shade=True, color='b')
